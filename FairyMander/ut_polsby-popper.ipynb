# %%
from fairymander.generator import DistrictGenerator

my_generator = DistrictGenerator("ut", 0.006, 6000, 3, "competitiveness")

districts = my_generator.run_and_save(directory="my_districts", file_prefix="ut_Polsby-Popper")
# Out:
# getting state GeoDataFrame
# Sucessfully loaded state GeoDataFrame
# getting state partition
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 from fairymander.generator import DistrictGenerator
#       3 my_generator = DistrictGenerator("ut", 0.006, 6000, 3, "competitiveness")
# ----> 5 districts = my_generator.run_and_save(directory="my_districts", file_prefix="ut_Polsby-Popper")
#
# File ~/Documents/GitHub/FairyMander/FairyMander/fairymander/generator.py:236, in DistrictGenerator.run_and_save(self, directory, file_prefix)
#     218 def run_and_save(self, directory: str, file_prefix: str) -> list[gpd.GeoDataFrame]:
#     219     """
#     220     Performs run, returns results and saves the result maps to the specified directory
#     221
#    (...)
#     234         are "dissolved", meaning the individual geographic units have been combined into districts
#     235     """
# --> 236     final_maps = self.run()
#     238     print(f"Saving maps to {directory}...")
#     239     for index, curr_map in enumerate(final_maps):
#
# File ~/Documents/GitHub/FairyMander/FairyMander/fairymander/generator.py:182, in DistrictGenerator.run(self)
#     180     display_metric = "Efficiency-Gap"
#     181 print("getting state partition")
# --> 182 init_partition=self._get_random_partition()
#     183 print("generating map")
#     184 best = self._generate_maps(init_partition)
#
# File ~/Documents/GitHub/FairyMander/FairyMander/fairymander/generator.py:71, in DistrictGenerator._get_random_partition(self)
#      62 """
#      63 Gets an initial random partition of the state to have a starting place for the algorithm
#      64
#    (...)
#      68     resulting random partition of the sate
#      69 """
#      70 # get the state's merged shapefile
# ---> 71 state_graph = Graph.from_geodataframe(self.state_gdf)
#      73 simulated_election = updaters.Election(
#      74 "Simulated Election",
#      75 {"Democratic": "party_dem", "Republican": "party_rep"},
#      76 alias = "election"
#      77 )
#      79 partition_updaters = {
#      80     "population": updaters.Tally("C_TOT22"),
#      81     "cut_edges": updaters.cut_edges,
#      82 }
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/gerrychain/graph/graph.py:255, in Graph.from_geodataframe(cls, dataframe, adjacency, cols_to_add, reproject, ignore_errors, crs_override)
#     251     df = dataframe
#     253 # Generate dict of dicts of dicts with shared perimeters according
#     254 # to the requested adjacency rule
# --> 255 adjacencies = neighbors(df, adjacency)
#     256 graph = cls(adjacencies)
#     258 graph.geometry = df.geometry
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/gerrychain/graph/adjacency.py:24, in neighbors(df, adjacency)
#      18 if adjacency not in ("rook", "queen"):
#      19     raise ValueError(
#      20         "The adjacency parameter provided is not supported. "
#      21         'We support "queen" or "rook" adjacency.'
#      22     )
# ---> 24 return adjacencies[adjacency](df.geometry)
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/gerrychain/graph/adjacency.py:149, in rook(geometries)
#     139 def rook(geometries):
#     140     """
#     141     :param geometries: A Shapeley geometry object.
#     142     :type geometries: shapely.geometry.BaseGeometry
#    (...)
#     145     :rtype: Dict
#     146     """
#     147     return {
#     148         i: {j: data for j, data in neighbors.items() if data["shared_perim"] > 0}
# --> 149         for i, neighbors in queen(geometries).items()
#     150     }
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/gerrychain/graph/adjacency.py:129, in queen(geometries)
#     120 """
#     121 :param geometries: A Shapeley geometry object.
#     122 :type geometries: shapely.geometry.BaseGeometry
#    (...)
#     125 :rtype: Dict
#     126 """
#     127 intersection_pairs = warn_for_overlaps(intersections_with_neighbors(geometries))
# --> 129 return {
#     130     i: {
#     131         j: {"shared_perim": intersection.length}
#     132         for j, intersection in intersections.items()
#     133         if (not intersection.is_empty)
#     134     }
#     135     for i, intersections in intersection_pairs
#     136 }
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/gerrychain/graph/adjacency.py:102, in warn_for_overlaps(intersection_pairs)
#      91 """
#      92 :param intersection_pairs: An iterable of tuples of
#      93     the form (id, {neighbor_id: intersection})
#    (...)
#      99 :raises: UserWarning if there are overlaps among the given polygons
#     100 """
#     101 overlaps = set()
# --> 102 for i, intersections in intersection_pairs:
#     103     overlaps.update(
#     104         set(
#     105             tuple(sorted([i, j]))
#    (...)
#     108         )
#     109     )
#     110     yield (i, intersections)
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/gerrychain/graph/adjacency.py:85, in intersections_with_neighbors(geometries)
#      73 """
#      74 Generator yielding tuples of the form (id, {neighbor_id: intersection}).
#      75 The intersections may be empty!
#    (...)
#      81 :rtype: Generator
#      82 """
#      83 for i, neighbors in neighboring_geometries(geometries):
#      84     intersections = {
# ---> 85         j: geometries[i].intersection(geometries[j]) for j in neighbors
#      86     }
#      87     yield (i, intersections)
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/shapely/geometry/base.py:599, in BaseGeometry.intersection(self, other, grid_size)
#     593 def intersection(self, other, grid_size=None):
#     594     """
#     595     Returns the intersection of the geometries.
#     596
#     597     Refer to `shapely.intersection` for full documentation.
#     598     """
# --> 599     return shapely.intersection(self, other, grid_size=grid_size)
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/Documents/GitHub/FairyMander/FairyMander/.venv/lib/python3.12/site-packages/shapely/set_operations.py:131, in intersection(a, b, grid_size, **kwargs)
#     127         raise ValueError("grid_size parameter only accepts scalar values")
#     129     return lib.intersection_prec(a, b, grid_size, **kwargs)
# --> 131 return lib.intersection(a, b, **kwargs)
#
# KeyboardInterrupt:

# %%
from fairymander.data import get_curr_district_file
from fairymander.fairness import full_analysis, compare_maps

currentDistrictMap = get_curr_district_file('ut')

# %%
compare_maps(currentDistrictMap,districts[0])
# Out:
# Republicans won every district, so lopsided margin cannot be calculated
# Republicans won every district, so lopsided margin cannot be calculated
# Running Fairness Comparison Analysis
# ------------------------------------
# Average Polsby-Popper Score for Map 1: 0.35177133402784166
# Average Polsby-Popper Score for Map 2: 0.21558778882409596
# Map One has a better Polsby-Popper score
#
# Average Reock Score for Map 1: 0.44144460510304945
# Average Reock Score for Map 2: 0.40175541378378626
# Map One has a better Reock score
#
# Efficiency Gap for Map 1: 16.0107273216694
# Efficiency Gap for Map 2: -6.466213315528384
# Map Two has a better Efficiency Gap
#
# Mean Median Difference, Map One: 0.17064934836885648
# Mean Median Difference, Map Two: 1.1889956583632095
# Map One has a better Mean Median Difference
#
# One party won every district in Map One, so lopsided margin is not calculable.
# One party won every district in Map Two, so lopsided margin is not calculable.
#
# Dissimilarity index, Hispanic, for Map One: 0.10014581660315523
# Dissimilarity index, African American, for Map One: 0.07702774028196584
# Dissimilarity index, East and South Asian, for Map One: 0.03505348341901568
# Dissimilarity index, Native American, for Map One: 0.0832016395254596
# Dissimilarity index, Other, for Map One: 0.08106021709157518
# Dissimilarity index, Hispanic, for Map Two: 0.16150248384199534
# Dissimilarity index, African American, for Map Two: 0.2691296598378198
# Dissimilarity index, East and South Asian, for Map Two: 0.13150280491202754
# Dissimilarity index, Native American, for Map Two: 0.3154830237184918
# Dissimilarity index, Other, for Map Two: 0.08515868112725401
# Map One has a better Dissimilarity Index for Hispanic minority population
# Map One has a better Dissimilarity Index for African American minority population
# Map One has a better Dissimilarity Index for East and South Asian minority population
# Map One has a better Dissimilarity Index for Native American minority population
# Map One has a better Dissimilarity Index for Other minority population
#
# Comparison Summary
# -------------------
# Map One is better in 8 metrics:
# Polsby-Popper, Reock, Mean Median Difference, Dissimilarity Index: Hispanic, Dissimilarity Index: African American, Dissimilarity Index: East and South Asian, Dissimilarity Index: Native American, Dissimilarity Index: Other
#
# Map Two is better in 1 metrics:
# Efficiency Gap
#
# There were no ties.
#
# Overall, Map One has better metrics
