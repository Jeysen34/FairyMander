# %%
from fairymander.generator import DistrictGenerator

my_generator = DistrictGenerator("co", 0.004, 4000, 3, "competitiveness")

districts = my_generator.run_and_save(directory="my_districts", file_prefix="co_Polsby-Popper")
# Out:
# getting state GeoDataFrame
# Sucessfully loaded state GeoDataFrame
# getting state partition
# generating map
# Map with Efficiency-Gap metric 0.048813878490082015 found:
# Population in each district:
# District
# 0    685540
# 1    685680
# 2    686465
# 3    687400
# 4    688030
# 5    684880
# 6    683894
# 7    682880
# Name: C_TOT22, dtype: int32
# Map with Efficiency-Gap metric 0.04183142915289269 found:
# Population in each district:
# District
# 0    685745
# 1    687290
# 2    684169
# 3    685470
# 4    686735
# 5    687865
# 6    684345
# 7    683150
# Name: C_TOT22, dtype: int32
# Map with Efficiency-Gap metric 0.046188423654207826 found:
# Population in each district:
# District
# 0    686660
# 1    683740
# 2    683019
# 3    683170
# 4    686570
# 5    688140
# 6    687295
# 7    686175
# Name: C_TOT22, dtype: int32
# Dissolving maps...

# %%
from fairymander.data import get_curr_district_file
from fairymander.fairness import full_analysis, compare_maps

currentDistrictMap = get_curr_district_file('co')

# %%
compare_maps(currentDistrictMap,districts[1])
# Out:
# Running Fairness Comparison Analysis
# ------------------------------------
# Average Polsby-Popper Score for Map 1: 0.2646987522273566
# Average Polsby-Popper Score for Map 2: 0.2493256973913565
# Map One has a better Polsby-Popper score
#
# Average Reock Score for Map 1: 0.40412921802131907
# Average Reock Score for Map 2: 0.4084731678051132
# Map Two has a better Reock score
#
# Efficiency Gap for Map 1: -3.9795410799404953
# Efficiency Gap for Map 2: 4.507487862623809
# Map One has a better Efficiency Gap
#
# Mean Median Difference, Map One: 2.1637189252311284
# Mean Median Difference, Map Two: 2.9369916813397845
# Map One has a better Mean Median Difference
#
# Lopsided Margin Score, Map One: 3.2474624968772474
# Lopsided Margin Score, Map Two: 5.757787775700386
# Map One has a better Lopsided Margin Score
#
# Dissimilarity index, Hispanic, for Map One: 0.20994475900727091
# Dissimilarity index, African American, for Map One: 0.3975503149269471
# ...
