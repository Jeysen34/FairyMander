# %%
from fairymander.fairness import full_analysis, compare_maps
from fairymander.data import get_curr_district_file
import geodatasets as gpd
coEf0 = "/Users/ceannajarrett/Documents/GitHub/FairyMander/FairyMander/my_districts/co_efficiency-gap/co_efficiency-gap-0"
currentDistrictMap = get_curr_district_file('co')

# %%
compare_maps(currentDistrictMap,coEf0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 compare_maps(currentDistrictMap,coEf0)
#
# File ~/Documents/GitHub/FairyMander/FairyMander/fairymander/fairness.py:135, in compare_maps(map_one, map_two, verbose, show_maps)
#     132 ax[0].set_title("District Map One")
#     134 # Plot the second map
# --> 135 map_two.plot(column='District', ax=ax[1], legend=True, cmap="rainbow")
#     136 ax[1].set_title("District Map Two")
#     138 plt.tight_layout()
#
# AttributeError: 'str' object has no attribute 'plot'
