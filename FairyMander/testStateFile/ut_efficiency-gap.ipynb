# %%
from fairymander.generator import DistrictGenerator

my_generator = DistrictGenerator("ut", 0.005, 6000, 3, "compact")

districts = my_generator.run_and_save(directory="my_districts", file_prefix="ut_efficiency-gap")
# Out:
# getting state GeoDataFrame
# Sucessfully loaded state GeoDataFrame
# getting state partition
# generating map
# Map with Polsby-Popper metric 0.4223733705434546 found:
# Population in each district:
# District
# 0    781925
# 1    778090
# 2    785360
# 3    781700
# Name: C_TOT22, dtype: int32
# Map with Polsby-Popper metric 0.47958205409399146 found:
# Population in each district:
# District
# 0    784115
# 1    779290
# 2    779795
# 3    783875
# Name: C_TOT22, dtype: int32
# Map with Polsby-Popper metric 0.4622440941687877 found:
# Population in each district:
# District
# 0    783830
# 1    778090
# 2    783455
# 3    781700
# Name: C_TOT22, dtype: int32
# Dissolving maps...
# Maps dissolved.
# Saving maps to my_districts...
# Maps saved.

# %%
from fairymander.fairness import full_analysis, compare_maps
from fairymander.data import get_curr_district_file

map = get_curr_district_file('ut')

# %%
compare_maps(map, districts[1])
# Out:
# Republicans won every district, so lopsided margin cannot be calculated
# Republicans won every district, so lopsided margin cannot be calculated
# Running Fairness Comparison Analysis
# ------------------------------------
# Average Polsby-Popper Score for Map 1: 0.35177133402784166
# Average Polsby-Popper Score for Map 2: 0.4795820540939942
# Map Two has a better Polsby-Popper score
#
# Average Reock Score for Map 1: 0.44144460510304945
# Average Reock Score for Map 2: 0.5139746109722533
# Map Two has a better Reock score
#
# Efficiency Gap for Map 1: 16.0107273216694
# Efficiency Gap for Map 2: -6.46610783597085
# Map Two has a better Efficiency Gap
#
# Mean Median Difference, Map One: 0.17064934836885648
# Mean Median Difference, Map Two: 2.2927260762972383
# Map One has a better Mean Median Difference
#
# One party won every district in Map One, so lopsided margin is not calculable.
# One party won every district in Map Two, so lopsided margin is not calculable.
#
# Dissimilarity index, Hispanic, for Map One: 0.10014581660315523
# Dissimilarity index, African American, for Map One: 0.07702774028196584
# Dissimilarity index, East and South Asian, for Map One: 0.03505348341901568
# Dissimilarity index, Native American, for Map One: 0.0832016395254596
# Dissimilarity index, Other, for Map One: 0.08106021709157518
# Dissimilarity index, Hispanic, for Map Two: 0.1703185430431861
# Dissimilarity index, African American, for Map Two: 0.24377529037187975
# Dissimilarity index, East and South Asian, for Map Two: 0.1667859083851763
# Dissimilarity index, Native American, for Map Two: 0.3682975546142261
# Dissimilarity index, Other, for Map Two: 0.15441265714255664
# Map One has a better Dissimilarity Index for Hispanic minority population
# Map One has a better Dissimilarity Index for African American minority population
# Map One has a better Dissimilarity Index for East and South Asian minority population
# Map One has a better Dissimilarity Index for Native American minority population
# Map One has a better Dissimilarity Index for Other minority population
#
# Comparison Summary
# -------------------
# Map One is better in 6 metrics:
# Mean Median Difference, Dissimilarity Index: Hispanic, Dissimilarity Index: African American, Dissimilarity Index: East and South Asian, Dissimilarity Index: Native American, Dissimilarity Index: Other
#
# Map Two is better in 3 metrics:
# Polsby-Popper, Reock, Efficiency Gap
#
# There were no ties.
#
# Overall, Map One has better metrics
