# %%
from fairymander.generator import DistrictGenerator

my_generator = DistrictGenerator("az", 0.006, 5000, 3, "competitiveness")

districts = my_generator.run_and_save(directory="my_districts", file_prefix="az_polsbyPopper")
# Out:
# getting state GeoDataFrame
# Sucessfully loaded state GeoDataFrame
# getting state partition
# generating map
# Map with Efficiency-Gap metric 0.018604834220750377 found:
# Population in each district:
# District
# 0    741120
# 1    744450
# 2    742199
# 3    743709
# 4    742815
# 5    738105
# 6    741774
# 7    740830
# 8    746090
# Name: C_TOT22, dtype: int32
# Map with Efficiency-Gap metric 0.008440418426038897 found:
# Population in each district:
# District
# 0    743969
# 1    745929
# 2    743420
# 3    738415
# 4    738245
# 5    745040
# 6    743440
# 7    739050
# 8    743584
# Name: C_TOT22, dtype: int32
# Map with Efficiency-Gap metric 0.015514219288529548 found:
# Population in each district:
# District
# 0    743969
# 1    738185
# 2    744294
# 3    739465
# 4    738245
# 5    743990
# 6    743440
# 7    745920
# 8    743584
# Name: C_TOT22, dtype: int32
# Dissolving maps...
# Maps dissolved.
# Saving maps to my_districts...
# Maps saved.

# %%
from fairymander.fairness import full_analysis, compare_maps
from fairymander.data import get_curr_district_file

currentDistrictMap = get_curr_district_file('az')

# %%
compare_maps(currentDistrictMap, districts[2])
# Out:
# Running Fairness Comparison Analysis
# ------------------------------------
# Average Polsby-Popper Score for Map 1: 0.27683861437532703
# Average Polsby-Popper Score for Map 2: 0.21936327072956602
# Map One has a better Polsby-Popper score
#
# Average Reock Score for Map 1: 0.4167527727678522
# Average Reock Score for Map 2: 0.4003504444562588
# Map One has a better Reock score
#
# Efficiency Gap for Map 1: 18.41246198447224
# Efficiency Gap for Map 2: 1.5514570694434293
# Map Two has a better Efficiency Gap
#
# Mean Median Difference, Map One: 2.316903772649026
# Mean Median Difference, Map Two: -0.4814256878339196
# Map Two has a better Mean Median Difference
#
# Lopsided Margin Score, Map One: 8.610124992471825
# Lopsided Margin Score, Map Two: -1.7935005695016457
# Map Two has a better Lopsided Margin Score
#
# Dissimilarity index, Hispanic, for Map One: 0.34240579974481367
# Dissimilarity index, African American, for Map One: 0.2396280377587448
# ...
