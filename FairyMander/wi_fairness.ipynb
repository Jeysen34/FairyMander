# %%
from fairymander.fairness import full_analysis, compare_maps
import geopandas as gpd

efficiencyGap0 = gpd.read_file("Data/BlockGroupDistricts/wi/wi_Efficiency-Gap_districts1.zip")
efficiencyGap1 = gpd.read_file("Data/BlockGroupDistricts/wi/wi_Efficiency-Gap_districts2.zip")
poblyPopper0 = gpd.read_file("Data/BlockGroupDistricts/wi/wi_Polsby-Popper_districts1.zip")
poblyPopper1 = gpd.read_file("Data/BlockGroupDistricts/wi/wi_Polsby-Popper_districts2.zip")

# %%
compare_maps(efficiencyGap0,efficiencyGap1)
# Out:
# Running Fairness Comparison Analysis
# ------------------------------------
# Average Polsby-Popper Score for Map 1: 0.20338071795023938
# Average Polsby-Popper Score for Map 2: 0.19816412985353243
# Map One has a better Polsby-Popper score
#
# Average Reock Score for Map 1: 0.349532985358452
# Average Reock Score for Map 2: 0.3533072523374608
# Map Two has a better Reock score
#
# Efficiency Gap for Map 1: -0.008879508382255912
# Efficiency Gap for Map 2: 0.004123703892776475
# Map Two has a better Efficiency Gap
#
# Mean Median Difference, Map One: 8.677192552802747
# Mean Median Difference, Map Two: 8.677192552802747
# Both maps have the same Mean Median Difference
#
# Lobsided Margin Score, Map One: -5.199340005178641
# Lobsided Margin Score, Map Two: -5.1909370081955615
# Map Two has a better Lobsided Margin Score
#
# Dissimilarity index, Hispanic, for Map One: 0.308246633874099
# Dissimilarity index, African American, for Map One: 0.6450637018220288
# ...

# %%
compare_maps(poblyPopper0,poblyPopper1)
# Out:
# Running Fairness Comparison Analysis
# ------------------------------------
# Average Polsby-Popper Score for Map 1: 0.26639059389333114
# Average Polsby-Popper Score for Map 2: 0.28583543159547914
# Map Two has a better Polsby-Popper score
#
# Average Reock Score for Map 1: 0.39283399741452824
# Average Reock Score for Map 2: 0.4357120960837035
# Map Two has a better Reock score
#
# Efficiency Gap for Map 1: -1.7421294445701958
# Efficiency Gap for Map 2: -2.1889342663539475
# Map One has a better Efficiency Gap
#
# Mean Median Difference, Map One: 1.5699982130573331
# Mean Median Difference, Map Two: 7.320740632712969
# Map One has a better Mean Median Difference
#
# Lobsided Margin Score, Map One: -6.138522031351677
# Lobsided Margin Score, Map Two: -5.883024379792737
# Map Two has a better Lobsided Margin Score
#
# Dissimilarity index, Hispanic, for Map One: 0.3072885587077945
# Dissimilarity index, African American, for Map One: 0.6855925792255245
# ...

# %%
compare_maps(efficiencyGap1,poblyPopper0)
# Out:
# Running Fairness Comparison Analysis
# ------------------------------------
# Average Polsby-Popper Score for Map 1: 0.19816412985353243
# Average Polsby-Popper Score for Map 2: 0.26639059389333114
# Map Two has a better Polsby-Popper score
#
# Average Reock Score for Map 1: 0.3533072523374608
# Average Reock Score for Map 2: 0.39283399741452824
# Map Two has a better Reock score
#
# Efficiency Gap for Map 1: 0.004123703892776475
# Efficiency Gap for Map 2: -1.7421294445701958
# Map One has a better Efficiency Gap
#
# Mean Median Difference, Map One: 8.677192552802747
# Mean Median Difference, Map Two: 1.5699982130573331
# Map Two has a better Mean Median Difference
#
# Lobsided Margin Score, Map One: -5.1909370081955615
# Lobsided Margin Score, Map Two: -6.138522031351677
# Map One has a better Lobsided Margin Score
#
# Dissimilarity index, Hispanic, for Map One: 0.308246633874099
# Dissimilarity index, African American, for Map One: 0.6450637018220288
# ...

# %%
full_analysis(poblyPopper0)
# Out:
# Running Fairness Analysis
# -------------------------
# Average Polsby-Popper Score: 0.26639059389333114
#
# Average Reock Score: 0.39283399741452824
#
# Efficiency Gap: -1.7421294445701958
#
# Mean Median Difference: 1.5699982130573331
#
# Lobsided Margin Score: -6.138522031351677
#
# Dissimilarity index, Hispanic: 0.3072885587077945
# Dissimilarity index, African American: 0.6855925792255245
# Dissimilarity index, East and South Asian: 0.10404533546113319
# Dissimilarity index, Other: 0.13913250699438276

# %%
from fairymander.folium_converter import map_to_folium

res = map_to_folium('wi',poblyPopper0)

res
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
