# %%
from fairymander.fairness import full_analysis, compare_maps
import geopandas as gpd

efficiencyGap0 = gpd.read_file("Data/BlockGroupDistricts/ut/ut_Efficiency-Gap_districts0.zip")
efficiencyGap1 = gpd.read_file("Data/BlockGroupDistricts/ut/ut_Efficiency-Gap_districts1.zip")
poblyPopper0 = gpd.read_file("Data/BlockGroupDistricts/ut/ut_Polsby-Popper_districts1.zip")
poblyPopper1 = gpd.read_file("Data/BlockGroupDistricts/ut/ut_Polsby-Popper_districts2.zip")

# %%
full_analysis(efficiencyGap1)
# Out:
# Running Fairness Analysis
# -------------------------
# Average Polsby-Popper Score: 0.2976151208944493
#
# Average Reock Score: 0.3988017362133406
#
# Efficiency Gap: -6.46610783597085
#
# Mean Median Difference: -0.8061907572085109
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 full_analysis(efficiencyGap1)
#
# File ~/Documents/GitHub/FairyMander/FairyMander/fairymander/fairness.py:91, in full_analysis(test_map, verbose, show_map)
#      89     print("The Lobsided Margin test is a district competitiveness measure. It is the difference between the average percentages by which each party won in a district.")
#      90     print("A percent difference 0-100, where a negative (-) value indicates Republicans have been packed (i.e., a Democrat advantage), where a positive (+) value indicates Democrats have been packed (i.e., a Republican advantage")
# ...
